# %% [markdown]
# # Chapter 14 Coding Set - Zavier Christians

# %% [markdown]
# ## Programming Exercises - Number 2

# %% [markdown]
# This problem asks us to:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To complete this problem I am first going to have to import the SQLite3 module so that I can use its database functions. I am then going to have to create a database with the name 'phonebook' and use some CRUD functions to allow the user to create, read, update, and delete enteries from that database which is where "CRUD" gets its name.

# %% [markdown]
# Lets get started!

# %%
import sqlite3

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

conn.close
# Out:
# <function Connection.close()>

# %% [markdown]
# It did create the database that we needed.

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    
    create_table()
    
    conn.close
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()

if __name__ == '__main__':
    main()

# %% [markdown]
# I have now created a table with the colums that are needed!
#
# Now to make a function that adds data to the table.

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    
    create_table()
    create_row()
    
    conn.close
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    name = 'Tim'
    
    number = '555-999-0234'
    
    cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES ("Tim","555-999-0234")''')
               
    conn.commit()
    
if __name__ == '__main__':
    main()

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    
    create_table()
    create_row()
    
    conn.close
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    name = 'Tim'
    
    number = '555-999-0234'
    
    cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
    conn.commit()
    
if __name__ == '__main__':
    main()

# %% [markdown]
# Now that we have created the create row function we can move on to creating a read function.

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    
    create_table()
    
    read_everything()
        
    conn.close
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    name = 'Tim'
    
    number = '555-999-0234'
    
    cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
    conn.commit()
    
def read_everything():
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    
    
if __name__ == '__main__':
    main()
# Out:
# Tim 555-999-0234
# Tim 555-999-0234
# Tim 555-999-0234

# %% [markdown]
# Looks like our read function is working very well, now onto the update function!

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    
    create_table()
    update_row()
    read_everything()
        
    conn.close
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    name = 'Tim'
    
    number = '555-999-0234'
    
    cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
    conn.commit()
    
def read_everything():
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    

def update_row():
    
    name = "Tim"
    
    number = "777-023-2345"
    
    cur.execute('''UPDATE Entries
                   Set Number == ?
                   Where Name == ?''',
                   (number, name))
    conn.commit
    
if __name__ == '__main__':
    main()
# Out:
# Tim 777-023-2345
# Tim 777-023-2345
# Tim 777-023-2345

# %% [markdown]
# My update function seems to well too!
#
# Now to move on to the fourth and final function, that delete function!

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    
    create_table()
    delete_row()
    read_everything()
        
    conn.close
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    name = 'Tim'
    
    number = '555-999-0234'
    
    cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
    conn.commit()
    
def read_everything():
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    

def update_row():
    
    name = "Tim"
    
    number = "777-023-2345"
    
    cur.execute('''UPDATE Entries
                   Set Number == ?
                   Where Name == ?''',
                   (number, name))
    conn.commit
    
def delete_row():
    
    name = "Tim"
    
    cur.execute('''DELETE FROM Entries WHERE Name == "Tim"''')
    
    conn.commit
    
if __name__ == '__main__':
    main()

# %% [markdown]
# I think that is this problem all done! The row "Tim" has now been deleted!

# %% [markdown]
# I am going to add a few input functions to try and make the program a little easier to use.

# %%
def main():
    create_table()
    read_everything()
    create_row()
        
    close()
    
def create_table():
    opn()

    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
    close()
    
def create_row():
    opn()
    
    user = input('Would you like add a entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input("Enter name here, ")

        number = input("Enter number here, ")
        
        cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
        conn.commit()
        
        read_everything()
        
        close()
    elif user == 'N':
        pass
    else:
        print("Invalid input!")
        
def read_everything():
    opn()
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    
    close()
def update_row():
    opn()
    
    name = "Tim"
    
    number = "777-023-2345"
    
    cur.execute('''UPDATE Entries
                   Set Number == ?
                   Where Name == ?''',
                   (number, name))
    conn.commit
    
    close()
def delete_row():
    opn()
    
    name = "Tim"
    
    cur.execute('''DELETE FROM Entries WHERE Name == "Tim"''')
    
    conn.commit
    
    close()
def opn():
    conn = sqlite3.connect('phonebook.db')

    cur = conn.cursor()
    
def close():
    conn.close
    
if __name__ == '__main__':
    main()
# Out:
# Tim 555-999-0234
# Tim 555-999-0234
# Tim 555-999-0234
# Would you like add a entry? (Y/N) Y
# Enter name here, Norman
# Enter number here, 223-424-5652
# Tim 555-999-0234
# Tim 555-999-0234
# Tim 555-999-0234
# Norman 223-424-5652
# Tim 555-999-0234
# Tim 555-999-0234
# Tim 555-999-0234
# Norman 223-424-5652

# %% [markdown]
# The add seems to be working well!

# %%
def main():
    create_table()
    read_everything()
    create_row()
    update_row()
        
    close()
    
def create_table():
    opn()

    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
    close()
    
def create_row():
    opn()
    
    user = input('Would you like add an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input("Enter name here, ")

        number = input("Enter number here, ")
        
        cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
        conn.commit()
        
        read_everything()
        
        close()
    elif user == 'N':
        pass
    else:
        print("Invalid input!")
        
def read_everything():
    opn()
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    
    close()
def update_row():
    opn()
    
    user = input('Would you like update an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input('Enter the name of the person with the new number, ')

        number = input('Enter their new number: ')

        cur.execute('''UPDATE Entries
                       Set Number == ?
                       Where Name == ?''',
                       (number, name))
        conn.commit
        
        read_everything()

        close()
    elif user == 'N':
        pass
    else:
        print('Invalid input')
        
def delete_row():
    opn()
    
    name = "Tim"
    
    cur.execute('''DELETE FROM Entries WHERE Name == "Tim"''')
    
    conn.commit
    
    close()
def opn():
    conn = sqlite3.connect('phonebook.db')

    cur = conn.cursor()
    
def close():
    conn.close
    
if __name__ == '__main__':
    main()
# Out:
# Tim 555-999-0234
# Tim 555-999-0234
# Tim 555-999-0234
# Norman 223-424-5652
# Would you like add an entry? (Y/N) N
# Would you like update an entry? (Y/N) Y
# Enter the name of the person with the new number, Norman
# Enter their new number: 123-456-7890
# Tim 555-999-0234
# Tim 555-999-0234
# Tim 555-999-0234
# Norman 123-456-7890

# %% [markdown]
# Very exciting! The new update function is working great!

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    create_table()
    read_everything()
    create_row()
    update_row()
    delete_row()
    
    close()
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    user = input('Would you like add an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input("Enter name here, ")

        number = input("Enter number here, ")
        
        cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print("Invalid input!")
        
def read_everything():
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    
def update_row():
    
    user = input('Would you like update an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input('Enter the name of the person with the new number, ')

        number = input('Enter their new number: ')

        cur.execute('''UPDATE Entries
                       Set Number = ?
                       Where Name = ?''',
                       (number, name))
        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print('Invalid input')
        
def delete_row():
    
    user = input('Would you like delete an entry? (Y/N) ')
    
    if user == 'Y':
    
        name = input('Enter the name of the person that you would like to delete from the database, ')

        cur.execute('''DELETE FROM Entries WHERE Name = ?''',(name,))

        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print('Invalid input!')
    
if __name__ == '__main__':
    main()
# Out:
# Tim 555-999-0234
# Tim 555-999-0234
# Tim 555-999-0234
# Norman 123-456-7890
# Would you like add an entry? (Y/N) N
# Would you like update an entry? (Y/N) N
# Would you like delete an entry? (Y/N) Y
# Enter the name of the person that you would like to delete from the database, Tim
# Norman 123-456-7890

# %% [markdown]
# OK things seem to be working very well!
#
# Now I am going to do a bit of testing and this problem will be complete!

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    create_table()
    read_everything()
    create_row()
    update_row()
    delete_row()
    
    close()
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    user = input('Would you like add an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input("Enter name here, ")

        number = input("Enter number here, ")
        
        cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print("Invalid input!")
        
def read_everything():
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    
def update_row():
    
    user = input('Would you like update an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input('Enter the name of the person with the new number, ')

        number = input('Enter their new number: ')

        cur.execute('''UPDATE Entries
                       Set Number = ?
                       Where Name = ?''',
                       (number, name))
        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print('Invalid input')
        
def delete_row():
    
    user = input('Would you like delete an entry? (Y/N) ')
    
    if user == 'Y':
    
        name = input('Enter the name of the person that you would like to delete from the database, ')

        cur.execute('''DELETE FROM Entries WHERE Name = ?''',(name,))

        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print('Invalid input!')
    
if __name__ == '__main__':
    main()
# Out:
# Norman 123-456-7890
# Would you like add an entry? (Y/N) Y
# Enter name here, James
# Enter number here, 232-4566
# Norman 123-456-7890
# James  232-4566
# Would you like update an entry? (Y/N) N
# Would you like delete an entry? (Y/N) N

# %%
conn = sqlite3.connect('phonebook.db')

cur = conn.cursor()

def main():
    create_table()
    read_everything()
    create_row()
    update_row()
    delete_row()
    
    close()
    
def create_table():
    
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    conn.commit()
    
def create_row():
    
    user = input('Would you like add an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input("Enter name here, ")

        number = input("Enter number here, ")
        
        cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
               
        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print("Invalid input!")
        
def read_everything():
    
    cur.execute('''SELECT * FROM Entries''')
    
    results = cur.fetchall()
    
    for row in results:
        print(f'{row [0]:1} {row [1]:1}')
    
def update_row():
    
    user = input('Would you like update an entry? (Y/N) ')
    
    if user == 'Y':
        
        name = input('Enter the name of the person with the new number, ')

        number = input('Enter their new number: ')

        cur.execute('''UPDATE Entries
                       Set Number = ?
                       Where Name = ?''',
                       (number, name))
        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print('Invalid input')
        
def delete_row():
    
    user = input('Would you like delete an entry? (Y/N) ')
    
    if user == 'Y':
    
        name = input('Enter the name of the person that you would like to delete from the database, ')

        cur.execute('''DELETE FROM Entries WHERE Name = ?''',(name,))

        conn.commit()
        
        read_everything()
        
    elif user == 'N':
        pass
    else:
        print('Invalid input!')
    
if __name__ == '__main__':
    main()
# Out:
# Norman 123-456-7890
# James  232-4566
# Would you like add an entry? (Y/N) Y
# Enter name here, Paul
# Enter number here, 890-382-2567
# Norman 123-456-7890
# James  232-4566
# Paul 890-382-2567
# Would you like update an entry? (Y/N) Y
# Enter the name of the person with the new number, James
# Enter their new number: 232-456-0123
# Norman 123-456-7890
# James  232-4566
# Paul 890-382-2567
# Would you like delete an entry? (Y/N) N

# %%
#create the connect variable
conn = sqlite3.connect('phonebook.db')

#create the cursor variable
cur = conn.cursor()

#define the main function
def main():
    #call the create table function
    create_table()
    #call the read function
    read_everything()
    #call the create row function 
    create_row()
    #call the update row function
    update_row()
    #call the delete row function
    delete_row()
    
    #close the database
    conn.close()

#define the create table function
def create_table():
    
    #Create a table called entries if it does not exist with a colum called name and a colum called number
    cur.execute('''CREATE TABLE IF NOT EXISTS Entries (Name TEXT, Number TEXT)''')
    
    #commit the sql code to the database
    conn.commit()

#define the create row function 
def create_row():
    
    #assign the user input variable to the users input 
    user = input('Would you like add an entry? (Y/N) ')
    
    #if the user entered "Y" the execute the code below 
    if user == 'Y':
        
        #set name to the users input
        name = input("Enter name here, ")
        #set number to the users input
        number = input("Enter number here, ")
        
        #insert a row into the table with the users inputs as the variables 
        cur.execute('''INSERT INTO Entries (Name, Number)
                VALUES (?,?)''',(name,number))
        
        #commit the sql code to the database
        conn.commit()
        
        #call the read function
        read_everything()
        
    #if the user said "N" then pass 
    elif user == 'N':
        #do nothing 
        pass
    #if anything else is entered
    else:
        #print invalid input
        print("Invalid input!")
        
#define the read function 
def read_everything():
    
    #Select everything in the table entries
    cur.execute('''SELECT * FROM Entries''')
    
    #assign the variable results to the whole table
    results = cur.fetchall()
    
    #for each row in the table repeat the code below 
    for row in results:
        #print the first colum then the seconnd 
        print(f'{row [0]:1} {row [1]:1}')
    
#define the update row function
def update_row():
    
    #assign the user input variable to the users input 
    user = input('Would you like update an entry? (Y/N) ')
    
    #if the user entered "Y" the execute the code below 
    if user == 'Y':
        
        #assign name to the users input
        name = input('Enter the name of the person with the new number, ')
        
        #assign the number to the users input 
        number = input('Enter their new number: ')
        
        #Update the entry the user specified in their entries and update the number with the one they entered 
        cur.execute('''UPDATE Entries
                       Set Number == ?
                       Where Name == ?''',
                       (number, name))
        
        #commit the sql code to the database
        conn.commit()
        
        #call the read function
        read_everything()
        
    #if the user said "N" then pass 
    elif user == 'N':
        #do nothing 
        pass
    #if anything else is entered
    else:
        #print invalid input
        print("Invalid input!")

#Define the delete row function 
def delete_row():
    
    #set user to the users input 
    user = input('Would you like delete an entry? (Y/N) ')
    
    #if the user entered "Y" the execute the code below 
    if user == 'Y':
        
        #set name to the users input
        name = input('Enter the name of the person that you would like to delete from the database, ')
        
        #delete the row that the user entered
        cur.execute('''DELETE FROM Entries WHERE Name == ?''',(name,))
    
        #commit the sql code to the database
        conn.commit()
        
        #call the read function
        read_everything()
        
    #if the user said "N" then pass 
    elif user == 'N':
        #do nothing 
        pass
    #if anything else is entered
    else:
        #print invalid input
        print("Invalid input!")

#if the name contains "__main__" then run the main function
if __name__ == '__main__':
    #call the main function
    main()
# Out:
# Norman 123-456-7890
# James  235-089-2945
# Paul 234-0582-0213
# Would you like add an entry? (Y/N) N
# Would you like update an entry? (Y/N) N
# Would you like delete an entry? (Y/N) Y
# Enter the name of the person that you would like to delete from the database, James
# Norman 123-456-7890
# James  235-089-2945
# Paul 234-0582-0213

# %% [markdown]
# Perfect!
#
# That is this problem done!
