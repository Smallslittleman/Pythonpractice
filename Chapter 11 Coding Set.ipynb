# %% [markdown]
# # Chapter 11 Coding Set - Zavier Christians

# %% [markdown]
# ## Programming Exercises - Number 1

# %% [markdown]
# This question asks us to:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To complete this question I am going to have to make a class called 'Employee' as well as a subclass of employee called production worker. I will then have to use the input function to get the users inputs and the methods from the class and subclass to store the users inputs within the class.

# %% [markdown]
# Lets get started!

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self, emp_name):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self, emp_number):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number

# %% [markdown]
# Good start I think this is the employee class done!
#
# Now to start on the subclass.

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self, emp_name):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self, emp_number):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_num, h_pay):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__shift_num = shift_num
        self.__h_pay = h_pay
    
    def set_shift_num(self, shift_num):
        self.__shift_num = input("Enter employee shift number: ")
        
    def set_h_pay(self, h_pay):
        self.__h_pay = input("Enter employee hourly pay: ")
        
    def get_shift_num(self):
        return self.__shift_num
    
    def get_h_pay(self):
        return self.__h_pay

# %% [markdown]
# Looks like the class and the subclass are working properly as of now.
#
# Now to start on the acutal program.

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self, emp_name):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self, emp_number):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_num, h_pay):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__shift_num = shift_num
        self.__h_pay = h_pay
    
    def set_shift_num(self, shift_num):
        self.__shift_num = input("Enter employee shift number: ")
        
    def set_h_pay(self, h_pay):
        self.__h_pay = input("Enter employee hourly pay: ")
        
    def get_shift_num(self):
        return self.__shift_num
    
    def get_h_pay(self):
        return self.__h_pay
    
def main():
    print("Enter the employee data for Harold below.")
    
    Harold = ProductionWorker('test name', '0000', '0', '$0.00')
    
    print(f'{Harold.get_emp_name()}')

main()
# Out:
# Enter the employee data for Harold below.
# test name

# %% [markdown]
# Seems to be working so far!

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_num, h_pay):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__shift_num = shift_num
        self.__h_pay = h_pay
    
    def set_shift_num(self):
        self.__shift_num = input("Enter employee shift number: ")
        
    def set_h_pay(self):
        self.__h_pay = input("Enter employee hourly pay: ")
        
    def get_shift_num(self):
        return self.__shift_num
    
    def get_h_pay(self):
        return self.__h_pay
    
def main():
    print("Enter the employee data for Harold below.")
    
    Harold = ProductionWorker('test name', '0000', '0', '$0.00')
    
    Harold.set_emp_name()
    Harold.set_emp_number()
    Harold.set_shift_num()
    Harold.set_h_pay()

main()
# Out:
# Enter the employee data for Harold below.
# Enter employee name here: Harold
# Enter the employee's number: 1234
# Enter employee shift number: 1
# Enter employee hourly pay: $15.94

# %% [markdown]
# The set methods seem to be working well!
#
# Now to impliment the get methods.

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_num, h_pay):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__shift_num = shift_num
        self.__h_pay = h_pay
    
    def set_shift_num(self):
        self.__shift_num = input("Enter employee shift number: ")
        
    def set_h_pay(self):
        self.__h_pay = input("Enter employee hourly pay: ")
        
    def get_shift_num(self):
        return self.__shift_num
    
    def get_h_pay(self):
        return self.__h_pay
    
def main():
    print("Enter the employee data for Harold below.")
    
    Harold = ProductionWorker('test name', '0000', '0', '$0.00')
    
    Harold.set_emp_name()
    Harold.set_emp_number()
    Harold.set_shift_num()
    Harold.set_h_pay()
    
    print("You entered Harold's information as:")
    
    print(f'{Harold.get_emp_name}')
    print(f'{Harold.get_emp_number}')
    print(f'{Harold.get_shift_num}')
    print(f'{Harold.get_h_pay}')

    
   
if __name__ == '__main__':
    main()
# Out:
# Enter the employee data for Harold below.
# Enter employee name here: Harold
# Enter the employee's number: 1234
# Enter employee shift number: 1
# Enter employee hourly pay: $15.50
# You entered Harold's information as:
# <bound method Employee.get_emp_name of <__main__.ProductionWorker object at 0x000001A6B6AAF910>>
# <bound method Employee.get_emp_number of <__main__.ProductionWorker object at 0x000001A6B6AAF910>>
# <bound method ProductionWorker.get_shift_num of <__main__.ProductionWorker object at 0x000001A6B6AAF910>>
# <bound method ProductionWorker.get_h_pay of <__main__.ProductionWorker object at 0x000001A6B6AAF910>>

# %% [markdown]
# Something has gone wrong I think I forgot the paretheses again!

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_num, h_pay):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__shift_num = shift_num
        self.__h_pay = h_pay
    
    def set_shift_num(self):
        self.__shift_num = input("Enter employee shift number (1 for day shift, 2 for night shift): ")
        
    def set_h_pay(self):
        self.__h_pay = input("Enter employee hourly pay: ")
        
    def get_shift_num(self):
        return self.__shift_num
    
    def get_h_pay(self):
        return self.__h_pay
    
def main():
    print("Enter the employee data for Harold below.\n")
    
    Harold = ProductionWorker('test name', '0000', '0', '$0.00')
    
    Harold.set_emp_name()
    Harold.set_emp_number()
    Harold.set_shift_num()
    Harold.set_h_pay()
    
    print("You entered Harold's information as:\n")
    
    print(f'{Harold.get_emp_name()}')
    print(f'{Harold.get_emp_number()}')
    print(f'{Harold.get_shift_num()}')
    print(f'{Harold.get_h_pay()}')

    
   
if __name__ == '__main__':
    main()
# Out:
# Enter the employee data for Harold below.
#
# Enter employee name here: Harold
# Enter the employee's number: 1234
# Enter employee shift number (1 for day shift, 2 for night shift): 1
# Enter employee hourly pay: $14.50
# You entered Harold's information as:
#
# Harold
# 1234
# 1
# $14.50

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ProductionWorker(Employee):
    def __init__(self, emp_name, emp_number, shift_num, h_pay):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__shift_num = shift_num
        self.__h_pay = h_pay
    
    def set_shift_num(self):
        self.__shift_num = int(input("Enter employee shift number (1 for day shift, 2 for night shift): "))
        
    def set_h_pay(self):
        self.__h_pay = input("Enter employee hourly pay: ")
        
    def get_shift_num(self):
        return self.__shift_num
    
    def get_h_pay(self):
        return self.__h_pay
    
def main():
    shift = ''
    
    print("Enter the employee data for Harold below.\n")
    
    Harold = ProductionWorker('test name', '0000', '0', '$0.00')
    
    Harold.set_emp_name()
    Harold.set_emp_number()
    Harold.set_shift_num()
    Harold.set_h_pay()
    
    print()
    print("You entered Harold's information as:\n")
    
    print(f'{Harold.get_emp_name()}')
    print(f'{Harold.get_emp_number()}')

    if Harold.get_shift_num() == 1:
        shift = "Day shift"
    elif Harold.get_shift_num() == 2:
        shift = "Night shift"
    else:
        shift = "Invalid shift number entered"
    
    print(f'{shift}')
    print(f'{Harold.get_h_pay()}')

    
   
if __name__ == '__main__':
    main()
# Out:
# Enter the employee data for Harold below.
#
# Enter employee name here: Harold
# Enter the employee's number: 1234
# Enter employee shift number (1 for day shift, 2 for night shift): 1
# Enter employee hourly pay: $13.50
#
# You entered Harold's information as:
#
# Harold
# 1234
# Day shift
# $13.50

# %% [markdown]
# Now to clean up the code a little bit more.

# %%
#define the Employee class
class Employee:
    #define the __init__ method with the employees name and the employees number as attributes
    def __init__(self, emp_name, emp_number):
        
        #set the init name attribute
        self.__emp_name = emp_name
        #set the init number attribute 
        self.__emp_number = emp_number
    
    #Define the set name method
    def set_emp_name(self):
        #set the name to the users input
        self.__emp_name = input('Enter employee name here: ')
        
    #define the set emp number method
    def set_emp_number(self):
        #set the employee number to the users input
        self.__emp_number = input("Enter the employee's number: ")
    
    #define the get employee name method
    def get_emp_name(self):
        #return the employee name
        return self.__emp_name

    #define the get employee number method
    def get_emp_number(self):
        #return the employees number
        return self.__emp_number
    
#define the ProductionWorker subclass which uses the Employee superclass
class ProductionWorker(Employee):
    #define the __init__ method for the ProductionWorker class with the employees name, number, shift, and pay as attributes
    def __init__(self, emp_name, emp_number, shift_num, h_pay):
        
        #call apon the employee classes init method to reuse it for the ProductionWorker class
        Employee.__init__(self, emp_name, emp_number)
        #set the shift num
        self.__shift_num = shift_num
        #set the hourly pay
        self.__h_pay = h_pay
    
    #define the set shift method 
    def set_shift_num(self):
        #set the shift number to the users input
        self.__shift_num = int(input("Enter employee shift number (1 for day shift, 2 for night shift): "))
        
    #define the set pay method
    def set_h_pay(self):
        #set the hourly pay to the users input
        self.__h_pay = input("Enter employee hourly pay: ")
        
    #define the get shift number method
    def get_shift_num(self):
        #return the shift number
        return self.__shift_num
    
    #define the get hourly pay method
    def get_h_pay(self):
        #return the hourly pay
        return self.__h_pay
    
#set the "Harold" object to some basic information to initialize the class
Harold = ProductionWorker('test name', '0000', '0', '$0.00')

#define the main function
def main():
    #print the directions for the user
    print("Enter the employee data for Harold below.\n")
    
    #call the inputs function
    inputs()
    #call the outputs function
    outputs()
    
#define the inputs function
def inputs():
    
    #call the set emp name method
    Harold.set_emp_name()
    #call the set emp number method 
    Harold.set_emp_number()
    #call the set shift number method
    Harold.set_shift_num()
    #call the set hourly pay method
    Harold.set_h_pay()
    
#define the outputs method
def outputs():
    #set the shift variable to a blank sting
    shift = ''
    
    #print a return
    print()
    #tell the user that the information they entered can be found below
    print("You entered Harold's information as:\n")
    
    #print the name they entered
    print(f'Name: {Harold.get_emp_name()}')
    #print the emp number they entered
    print(f'Employee number: {Harold.get_emp_number()}')
    
    #if the number they entered is 1 run the code below
    if Harold.get_shift_num() == 1:
        #set shift to "day shift"
        shift = "Day shift"
    #if the number they entered is 2 run the code below
    elif Harold.get_shift_num() == 2:
        #set shift to "night shift"
        shift = "Night shift"
    #if what they entered is anything other than a 1 or 2 run the code below
    else:
        #set shift to an error message
        shift = "Invalid shift number entered"
    
    #print the shift variable
    print(f'Shift: {shift}')
    #print the hourly rate the user entered
    print(f'Hourly pay: {Harold.get_h_pay()}')
    
   
 #if the file name contains '__main__' run the 'main' function    
if __name__ == '__main__':
    #Call the main function
    main()
# Out:
# Enter the employee data for Harold below.
#
# Enter employee name here: Harold
# Enter the employee's number: 1234
# Enter employee shift number (1 for day shift, 2 for night shift): 1
# Enter employee hourly pay: $12.50
#
# You entered Harold's information as:
#
# Name: Harold
# Employee number: 1234
# Shift: Day shift
# Hourly pay: $12.50

# %% [markdown]
# Looking good, I think this problem is done!

# %% [markdown]
# ## Programming Exercises - Number 2

# %% [markdown]
# This problem asks us to:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# To complete this problem I am going to have to use the code from above to create another subclass called "ShiftSupervisor".
#
# I am going to have to use the input function once again to store the users inputs as the attributes for the said supervisor and am going to have to create two more get and set methods within the new subclass which set and get the annual salary and the production bonus.

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ShiftSupervisor:
    def __init__(self, emp_name, emp_number, annual_sal, pro_bonus):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__annual_sal = annual_sal
        self.__pro_bonus = pro_bonus
        
    def set_annual_sal(self):
        self.__annual_sal = input("Enter supervisor's annual salary: ")
    
    def set_pro_bonus(self):
        self.pro_bonus = input("Enter supervisor's annual production bonus: ")
        
    def get_annual_sal(self):
        return self.__annual_sal
    
    def get_pro_bonus(self):
        return self.__pro_bonus

# %% [markdown]
# Everything seems to be working well so far with the subclass
#
# Now onto the code which will use it!

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ShiftSupervisor(Employee):
    def __init__(self, emp_name, emp_number, annual_sal, pro_bonus):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__annual_sal = annual_sal
        self.__pro_bonus = pro_bonus
        
    def set_annual_sal(self):
        self.__annual_sal = input("Enter supervisor's annual salary: ")
    
    def set_pro_bonus(self):
        self.pro_bonus = input("Enter supervisor's annual production bonus: ")
        
    def get_annual_sal(self):
        return self.__annual_sal
    
    def get_pro_bonus(self):
        return self.__pro_bonus
    
Kevin = ShiftSupervisor('test name','0000','$0.00','$0.00')

def main():
    
    print("Enter A shift supervisor's information below.\n")
    
    inputs()
    outputs()
    
def inputs():
    
    Kevin.set_emp_name()
    Kevin.set_emp_number()
    Kevin.set_annual_sal()
    Kevin.set_pro_bonus()
    
if __name__ == '__main__':
    main()
# Out:
# Enter A shift supervisor's information below.
#
# Enter employee name here: Kevin
# Enter the employee's number: 4321
# Enter supervisor's annual salary: $45,000
# Enter supervisor's annual production bonus: $5,500
#
# You entered Harold's information as:
#
# Name: Harold
# Employee number: 1234
# Shift: Day shift
# Hourly pay: $12.50

# %% [markdown]
# Looks like the set methods seem to be working. However I have called apon the outputs function from problem number 1's code.
#
# I am now going to create the outputs function for this code.

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ShiftSupervisor(Employee):
    def __init__(self, emp_name, emp_number, annual_sal, pro_bonus):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__annual_sal = annual_sal
        self.__pro_bonus = pro_bonus
        
    def set_annual_sal(self):
        self.__annual_sal = input("Enter supervisor's annual salary: ")
    
    def set_pro_bonus(self):
        self.pro_bonus = input("Enter supervisor's annual production bonus: ")
        
    def get_annual_sal(self):
        return self.__annual_sal
    
    def get_pro_bonus(self):
        return self.__pro_bonus
    
Kevin = ShiftSupervisor('test name','0000','$0.00','$0.00')

def main():
    
    print("Enter A shift supervisor's information below.\n")
    
    inputs()
    outputs()
    
def inputs():
    
    Kevin.set_emp_name()
    Kevin.set_emp_number()
    Kevin.set_annual_sal()
    Kevin.set_pro_bonus()
    
    
def outputs():
    
    print("This is what you entered as the supervisor's information")
    
    print(f'{Kevin.get_emp_name()}')
    print(f'{Kevin.get_emp_number()}')
    print(f'{Kevin.get_annual_sal()}')
    print(f'{Kevin.get_pro_bonus()}')
    
if __name__ == '__main__':
    main()
# Out:
# Enter A shift supervisor's information below.
#
# Enter employee name here: Kevin
# Enter the employee's number: 4321
# Enter supervisor's annual salary: $40,000
# Enter supervisor's annual production bonus: $5,000
# This is what you entered as the supervisor's information
# Kevin
# 4321
# $40,000
# $0.00

# %% [markdown]
# Looks like the set method for the production bonus is not working. Time to troubleshoot!

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ShiftSupervisor(Employee):
    def __init__(self, emp_name, emp_number, annual_sal, pro_bonus):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__annual_sal = annual_sal
        self.__pro_bonus = pro_bonus
        
    def set_annual_sal(self):
        self.__annual_sal = input("Enter supervisor's annual salary: ")
    
    def set_pro_bonus(self):
        self.__pro_bonus = input("Enter supervisor's annual production bonus: ")
        
    def get_annual_sal(self):
        return self.__annual_sal
    
    def get_pro_bonus(self):
        return self.__pro_bonus
    
Kevin = ShiftSupervisor('test name','0000','$0.00','$0.00')

def main():
    
    print("Enter A shift supervisor's information below.\n")
    
    inputs()
    outputs()
    
def inputs():
    
    Kevin.set_emp_name()
    Kevin.set_emp_number()
    Kevin.set_annual_sal()
    Kevin.set_pro_bonus()
    
    
def outputs():
    
    print("This is what you entered as the supervisor's information")
    
    print(f'{Kevin.get_emp_name()}')
    print(f'{Kevin.get_emp_number()}')
    print(f'{Kevin.get_annual_sal()}')
    print(f'{Kevin.get_pro_bonus()}')
    
if __name__ == '__main__':
    main()
# Out:
# Enter A shift supervisor's information below.
#
# Enter employee name here: Kevin
# Enter the employee's number: 4321
# Enter supervisor's annual salary: $35,000
# Enter supervisor's annual production bonus: $4,500
# This is what you entered as the supervisor's information
# Kevin
# 4321
# $35,000
# $4,500

# %% [markdown]
# That looks very good!
#
# Now to clean up the result and the code a little bit!

# %%
class Employee:
    def __init__(self, emp_name, emp_number):
        
        self.__emp_name = emp_name
        self.__emp_number = emp_number
        
    def set_emp_name(self):
        self.__emp_name = input('Enter employee name here: ')
        
    def set_emp_number(self):
        self.__emp_number = input("Enter the employee's number: ")
        
    def get_emp_name(self):
        return self.__emp_name
    
    def get_emp_number(self):
        return self.__emp_number
    
class ShiftSupervisor(Employee):
    def __init__(self, emp_name, emp_number, annual_sal, pro_bonus):
        
        Employee.__init__(self, emp_name, emp_number)
        self.__annual_sal = annual_sal
        self.__pro_bonus = pro_bonus
        
    def set_annual_sal(self):
        self.__annual_sal = input("Enter supervisor's annual salary: ")
    
    def set_pro_bonus(self):
        self.__pro_bonus = input("Enter supervisor's annual production bonus: ")
        
    def get_annual_sal(self):
        return self.__annual_sal
    
    def get_pro_bonus(self):
        return self.__pro_bonus
    
Kevin = ShiftSupervisor('test name','0000','$0.00','$0.00')

def main():
    
    print()
    print("Enter A shift supervisor's information below.\n")
    
    inputs()
    outputs()
    
def inputs():
    
    Kevin.set_emp_name()
    Kevin.set_emp_number()
    Kevin.set_annual_sal()
    Kevin.set_pro_bonus()
    
    
def outputs():
    
    print("This is what you entered as the supervisor's information")
    
    print(f'Name: {Kevin.get_emp_name()}')
    print(f'Employee number: {Kevin.get_emp_number()}')
    print(f'Annual salary{Kevin.get_annual_sal()}')
    print(f'Annual production bonus: {Kevin.get_pro_bonus()}')
    
if __name__ == '__main__':
    main()
# Out:
# Enter A shift supervisor's information below.
#
# Enter employee name here: Kevin
# Enter the employee's number: 4321
# Enter supervisor's annual salary: $30,000
# Enter supervisor's annual production bonus: $4,000
# This is what you entered as the supervisor's information
# Name: Kevin
# Employee number: 4321
# Annual salary$30,000
# Annual production bonus: $4,000

# %%
#define the Employee class
class Employee:
    #define the __init__ method with the employees name and the employees number as attributes
    def __init__(self, emp_name, emp_number):
        
        #set the init name attribute
        self.__emp_name = emp_name
        #set the init number attribute 
        self.__emp_number = emp_number
    
    #Define the set name method
    def set_emp_name(self):
        #set the name to the users input
        self.__emp_name = input('Enter employee name here: ')
        
    #define the set emp number method
    def set_emp_number(self):
        #set the employee number to the users input
        self.__emp_number = input("Enter the employee's number: ")
    
    #define the get employee name method
    def get_emp_name(self):
        #return the employee name
        return self.__emp_name

    #define the get employee number method
    def get_emp_number(self):
        #return the employees number
        return self.__emp_number

#define the ShiftSupervisor subclass which uses the Employee superclass
class ShiftSupervisor(Employee):
    #define the init function with the supervisors name, employee number, annual salary, and production bonus as attributes
    def __init__(self, emp_name, emp_number, annual_sal, pro_bonus):
        
        #call the init method from the Employee superclass to set the emp name and number
        Employee.__init__(self, emp_name, emp_number)
        #set the annual salary 
        self.__annual_sal = annual_sal
        #set the production bonus
        self.__pro_bonus = pro_bonus
        
    #define the set annual salary method   
    def set_annual_sal(self):
        #set the annual salary to the users input 
        self.__annual_sal = input("Enter supervisor's annual salary: ")
    
    #define the set production bonus method
    def set_pro_bonus(self):
        #set the production bonus to the users input 
        self.__pro_bonus = input("Enter supervisor's annual production bonus: ")
        
    #define the get annual salary method
    def get_annual_sal(self):
        #return the annual salary 
        return self.__annual_sal
    
    #define the get production bonus method
    def get_pro_bonus(self):
        #return the production bonus
        return self.__pro_bonus
    
#set the variable Kevin to some test attributes
Kevin = ShiftSupervisor('test name','0000','$0.00','$0.00')

#define a main function
def main():
    #print the directions for the user
    print("Enter A shift supervisor's information below.\n")
    
    #call the inputs function
    inputs()
    #call the outputs function 
    outputs()

#define the inputs function
def inputs():
    
    #call the set name method
    Kevin.set_emp_name()
    #call the set number method
    Kevin.set_emp_number()
    #call the set salary method 
    Kevin.set_annual_sal()
    #call the set bonus method
    Kevin.set_pro_bonus()
    
#define the outputs function
def outputs():
    
    #print a blank line 
    print()
    #tell the user that the text below is the information they entered 
    print("This is what you entered as the supervisor's information\n")
    
    #print the supervisors name
    print(f'Name: {Kevin.get_emp_name()}')
    #print the supervisors employee number
    print(f'Employee number: {Kevin.get_emp_number()}')
    #print the supervisors annual salary
    print(f'Annual salary{Kevin.get_annual_sal()}')
    #print the supervisors production bonus
    print(f'Annual production bonus: {Kevin.get_pro_bonus()}')
    
    
#if the file name contains '__main__' run the 'main' function    
if __name__ == '__main__':
    #Call the main function
    main()
# Out:
# Enter A shift supervisor's information below.
#
# Enter employee name here: Kevin
# Enter the employee's number: 4321
# Enter supervisor's annual salary: $25,000
# Enter supervisor's annual production bonus: $3,500
#
# This is what you entered as the supervisor's information
#
# Name: Kevin
# Employee number: 4321
# Annual salary$25,000
# Annual production bonus: $3,500

# %% [markdown]
# I think that is this problem all done!
