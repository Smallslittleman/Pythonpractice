# %% [markdown]
# # Chapter 10 Coding Set - Zavier Christians

# %% [markdown]
# ## Programming Exercises - Number 1

# %% [markdown]
# This problem asks us to:
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# To complete this problem I am going to use a seperate module that I am going to call pets.py which creates a class called "Pet".
#
# Within the class in the pets module I am going to make the methods that are above and call apon those methods in the code I write in the notebook.
#
# In the notebook code I am going to use the input functions so that the user can input there pets attributes, and then the program will tell them the attributes they input. That is the hope at least!

# %%
import pets

# %% [markdown]
# This is the start of my module which is contained in the pets.py text file

# %%
class pet: 
    def __init__(self, __name, __animal_type, __age):
        self.__name = __name
        self.__animal_type = __animal_type
        self.__age = __age
    
    def set_name():
        self.__name = input("Write your pets name, ")
    
    def set_animal_type():
        self.__animal_type = input("Write what type of animal your is, ")
    
    def set_age():
        self.__age = input("Write your pets age, ")
    
    def get_name():
        pass
    
    def get_animal_type():
        pass
    
    def get_age():
        pass

# %%
import pets

# %% [markdown]
# Now I am going to set the initial values in the class

# %%
my_pet = pets.pet("David","Dog",'21')

# %% [markdown]
# It worked!
#
# Now I am going to call the set name method to see if that works too

# %%
my_pet.set_name()
# Out:
# Write your pets name, Daniel

# %%
my_pet.get_name()
# Out:
# Pets name is: Daniel

# %%
my_pet.get_age()
# Out:
# Pets age is: 21

# %% [markdown]
# Everything seems to be working so far!

# %% [markdown]
# Now I am going to make the code which runs the external module.

# %%
#import the pets module
import pets

#define the main function
def main():
    #create a new pet class called 'my_pet' and set the initial attributes to some filler variables
    my_pet = pets.pet("Filler Name", "Example animal", "0")
    
    #call the set name method so the user can input there own pets name
    my_pet.set_name()
    #call the set animal type method so the user can input there pets animal type
    my_pet.set_animal_type()
    #call the set age method so the user can input there pets age 
    my_pet.set_age()
    
    #print something that tells the user that it is going to show the information they just input
    print("Your pets information: \n")
    
    #call the get name method so the user can see what they input
    my_pet.get_name()
    #call the get animal type method so the user can see what they input 
    my_pet.get_animal_type()
    #call the get age method so the user can see what they input
    my_pet.get_age()
    
    
#if the file name contains '__main__' run the 'main' function    
if __name__ == '__main__':
    #Call the main function
    main()
# Out:
# Write your pets name, Harry
# Write what type of animal your is, horse
# Write your pets age, 14
# Your pets information:
#
# Pets name is: Harry
# The pet is a: horse
# Pets age is: 14

# %% [markdown]
# I think that is this problem done, I struggled for a while because I could not understand why my module was not importing only to find out it was because I hadnt ever saved it. Hopefully I wont make that mistake again, but I'm glad I did because I learned a lot from it!

# %% [markdown]
# ## Programming Excercises - Number 4

# %% [markdown]
# This problem asks us to:
# ![image.png](attachment:image.png)

# %% [markdown]
# To complete this problem I am going to make a seperate module called emp_class which will contain the class and methods.
#
# I will then call apon that module and run the methods within to set and show the information input by the user.
#
# I will have to use the import function and multiple input functions to accomplish these items. I will also likely have to use some loops and possibly some if statments.

# %% [markdown]
# Below is the code which contained within the module in the emp_class.py file

# %%
class employee:
    def __init__(self, name, ID_number, department, job_title):
        self.__name = name
        self.__ID_number = ID_number
        self.__department = deparment
        self.__job_title = job_title
        
    def set_name(self):
        self.__name = input("Enter employee's name, ")
        
    def set_ID_number(self):
        self.__ID_number = input("Enter employee's ID number: ")
        
    def set_department(self):
        self.__department = input("Enter employee's department, ")
        
    def set_job_title(self):
        self.__job_title = input("Enter employee's job title, ")
        
    def get_name(self):
        return self.__name
    
    def get_ID_number(self):
        return self.__ID_number
    
    def get_department(self):
        return self.__department
    
    def get_job_title(self):
        return self.__job_title

# %%
import emp_class

# %% [markdown]
# Now I am going to make the code which uses the module.

# %%
import emp_class

def main():
    
    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")

# %% [markdown]
# Everything seems to work so far!
# Now to continue.

# %%
import emp_class

def main():
    number_of_emps = int(input("How many employees are you entering? "))

    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
    
main()
# Out:
# How many employees are you entering? 12

# %%
import emp_class

def main():
    number_of_emps = int(input("How many employees are you entering? "))

    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
    
    for name in range(0,number_of_emps):
        print('test')
    
main()
# Out:
# How many employees are you entering? 3
# test
# test
# test

# %%
import emp_class

def main():
    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
    
    user_input()
    
        
def user_input():
    names = []
    number_of_emps = int(input("How many employees are you entering? "))
    
    for item in range(0,number_of_emps):
        name = input(f"Enter employee number {item+1}'s name, ")
        ID_number = input(f"Enter {name}'s ID number: ")
        department = input(f"Enter {name}'s department, ")
        job_title = input(f"Enter {name}'s job title, ")
        
        print(f'{name}, {ID_number}, {department}, {job_title}')   
        
main()
# Out:
# How many employees are you entering? 2
# Enter employee number 1's name, sam
# Enter sam's ID number: 2323
# Enter sam's department, law
# Enter sam's job title, dad
# sam, 2323, law, dad
# Enter employee number 2's name, tod
# Enter tod's ID number: 2452
# Enter tod's department, pool boy
# Enter tod's job title, djawbd
# tod, 2452, pool boy, djawbd

# %%
test = 1

blah = test

print(blah)
# Out:
# 1

# %%
import emp_class

def main():
    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
    
    user_input()
    
        
def user_input():
    names = []
    number_of_emps = int(input("How many employees are you entering? "))
    
    for item in range(0,number_of_emps):
        
        name = input(f"Enter employee number {item+1}'s name, ")
        
        ID_number = input(f"Enter {name}'s ID number: ")
        
        department = input(f"Enter {name}'s department, ")
        
        job_title = input(f"Enter {name}'s job title, ")
        
        names.append(name)
        print(names)
     
        
main()
# Out:
# How many employees are you entering? 4
# Enter employee number 1's name, dad
# Enter dad's ID number: wdawf
# Enter dad's department, awdawd
# Enter dad's job title, wadawd
# ['dad']
# Enter employee number 2's name, tod
# Enter tod's ID number: dawd
# Enter tod's department, dawd
# Enter tod's job title, awd
# ['dad', 'tod']
# Enter employee number 3's name, harper
# Enter harper 's ID number: wada
# Enter harper 's department, awd
# Enter harper 's job title, aw
# ['dad', 'tod', 'harper ']
# Enter employee number 4's name, kevin
# Enter kevin's ID number: dawd
# Enter kevin's department, awd
# Enter kevin's job title, awd
# ['dad', 'tod', 'harper ', 'kevin']

# %%
import emp_class

def main():
    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
    
    number_of_emps = int(input("How many employees are you entering? "))
    
    print(user_input(number_of_emps))
    
        
def user_input(number_of_emps):
    names = []
    
    for item in range(0,number_of_emps):
        
        name = input(f"Enter employee number {item+1}'s name, ")
        
        ID_number = input(f"Enter {name}'s ID number: ")
        
        department = input(f"Enter {name}'s department, ")
        
        job_title = input(f"Enter {name}'s job title, ")
        
        names.append(name)
        
        current_emp = emp_class.employee(name, ID_number, department, job_title)
    
    return names
           
main()
# Out:
# How many employees are you entering? 2
# Enter employee number 1's name, Monica
# Enter Monica's ID number: 24223
# Enter Monica's department, law
# Enter Monica's job title, lawer
# Enter employee number 2's name, harry
# Enter harry's ID number: 2425
# Enter harry's department, law
# Enter harry's job title, lawer
# ['Monica', 'harry']

# %%
import emp_class

def main():
    
    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
    
    number_of_emps = int(input("How many employees are you entering? "))
    
    
    output(user_input(number_of_emps))
    
        
def user_input(number_of_emps):
    names = []
    
    for item in range(0,number_of_emps):
        
        name = input(f"Enter employee number {item+1}'s name, ")
        
        ID_number = input(f"Enter {name}'s ID number: ")
        
        department = input(f"Enter {name}'s department, ")
        
        job_title = input(f"Enter {name}'s job title, ")
        
        names.append(name)
        
        current_emp = emp_class.employee(name, ID_number, department, job_title)
    
    return names

def output(names_list):
    
    for emp in names_list:
            print("Name", emp.get_name())
        
        
    
main()
# Out:
# How many employees are you entering? 1
# Enter employee number 1's name, dawd
# Enter dawd's ID number: awdaw
# Enter dawd's department, dawd
# Enter dawd's job title, awd
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 39
#      34     for emp in names_list:
#      35             print("Name", emp.get_name())
# ---> 39 main()
#
# Cell In[9], line 10, in main()
#       5 initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
#       7 number_of_emps = int(input("How many employees are you entering? "))
# ---> 10 output(user_input(number_of_emps))
#
# Cell In[9], line 35, in output(names_list)
#      32 def output(names_list):
#      34     for emp in names_list:
# ---> 35             print("Name", emp.get_name())
#
# AttributeError: 'str' object has no attribute 'get_name'

# %% [markdown]
# So after about an hour of trial and error as well as some research and help from ChatGPT I realized that you cannot do this how I wanted to. This is because as far as I can tell you cant have the object of the argument be a variable because it is evaluated immediatly by the code.
#
# I am going to try to start over with the problem from this point on and do that problem in a much more simple way.

# %%
#define a main function
def main(): 
    #set the intial object to some test information
    initial = emp_class.employee("test name", "00000", "tesing lab", "tester")
    
    #set the Susan_Meyers object to her information
    Susan_Meyers = emp_class.employee("Susan Meyers", "47899", "Accounting", "Vice President")
    
    #set the Mark_Jones object to his information
    Mark_Jones = emp_class.employee("Mark Jones", "39119", "IT", "Programmer")
    
    #set the Joy_Rogers object to her information
    Joy_Rogers = emp_class.employee("Joy Rogers", "81774", "Manufacturing", "Engineer")
    
    #print a line that say that the below information is Susans
    print("Susan Meyers employee information, \n")
    
    #print Susans name
    print(f'{Susan_Meyers.get_name()}')
    #print her ID number
    print(f'{Susan_Meyers.get_ID_number()}')
    #print her department
    print(f'{Susan_Meyers.get_department()}')
    #print her job title
    print(f'{Susan_Meyers.get_job_title()}\n')
    
    #print a line stating that the information below is Marks
    print("Mark Jones employee information, \n")
    
    #print Marks name
    print(f'{Mark_Jones.get_name()}')
    #print his ID number
    print(f'{Mark_Jones.get_ID_number()}')
    #print his department 
    print(f'{Mark_Jones.get_department()}')
    #print his job title
    print(f'{Mark_Jones.get_job_title()}\n')
    
    #print a line stating that the information below is Joys
    print("Joy Rogers employee information, \n")
    
    #print Joys name
    print(f'{Joy_Rogers.get_name()}')
    #print her ID number
    print(f'{Joy_Rogers.get_ID_number()}')
    #print her department
    print(f'{Joy_Rogers.get_department()}')
    #print her job title
    print(f'{Joy_Rogers.get_job_title()}\n')

#if the file name contains '__main__' run the 'main' function    
if __name__ == '__main__':
    #Call the main function
    main()
# Out:
# Susan Meyers employee information,
#
# Susan Meyers
# 47899
# Accounting
# Vice President
#
# Mark Jones employee information,
#
# Mark Jones
# 39119
# IT
# Programmer
#
# Joy Rogers employee information,
#
# Joy Rogers
# 81774
# Manufacturing
# Engineer

# %% [markdown]
# After a lot of thinking and trial and error I think this problem is finally done!
